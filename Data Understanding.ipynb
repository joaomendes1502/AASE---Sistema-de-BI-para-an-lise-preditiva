# %%
import pandas as pd

# %%
df = pd.read_csv('./train.csv')
df.head()
# Out:
#                                            full_name registered_year  \
# 0                            2019 Tata Tiago XZ Plus        Nov 2019
# 1                          2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                          2015 Honda City i VTEC SV        May 2015
# 3  2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                    2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
#
#   engine_capacity              insurance transmission_type  kms_driven  \
# 0         1199 cc            Third Party            Manual  30,910 Kms
# 1         1199 cc               Zero Dep            Manual  48,089 Kms
# 2         1497 cc  Third Party insurance            Manual  51,000 Kms
# 3         1956 cc  Third Party insurance         Automatic  30,000 Kms
# 4         1197 cc               Zero Dep         Automatic  61,113 Kms
#
#      owner_type fuel_type  max_power  seats     mileage  body_type     city  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13956 entries, 0 to 13955
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          13956 non-null  object
#  1   registered_year    13902 non-null  object
#  2   engine_capacity    13947 non-null  object
#  3   insurance          13951 non-null  object
#  4   transmission_type  13956 non-null  object
#  5   kms_driven         13953 non-null  object
#  6   owner_type         13920 non-null  object
#  7   fuel_type          13956 non-null  object
#  8   max_power          13867 non-null  object
#  9   seats              13949 non-null  float64
#  10  mileage            13549 non-null  object
#  11  body_type          13956 non-null  object
#  12  city               13956 non-null  object
#  13  resale_price_Lakh  13956 non-null  float64
# dtypes: float64(2), object(12)
# memory usage: 1.5+ MB

# %%
df.columns
# Out:
# Index(['full_name', 'registered_year', 'engine_capacity', 'insurance',
#        'transmission_type', 'kms_driven', 'owner_type', 'fuel_type',
#        'max_power', 'seats', 'mileage', 'body_type', 'city',
#        'resale_price_Lakh'],
#       dtype='object')

# %%
(new_df['engine_capacity'] == 0).value_counts()
# Out:
# engine_capacity
# False    13956
# Name: count, dtype: int64

# %%
#new_df.hist(bins=60,figsize=(20,10))

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'Electric', 'LPG'], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group the data by 'fuel_type' and calculate the mean resale price for each fuel type
fuel_price_mean = new_df.groupby('fuel_type')['resale_price_Lakh'].mean()

# Plot the data
fuel_price_mean.plot(kind='bar', color='skyblue')
plt.title('Mean Resale Price by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Mean Resale Price (Lakh)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Convert 'kms_driven' to numeric (if not done already)
new_df['kms_driven'] = new_df['kms_driven'].str.replace(',', '').str.replace('Kms', '').astype(float)

# Create a scatter plot
plt.scatter(new_df['kms_driven'], new_df['resale_price_Lakh'], alpha=0.5, color='purple')
plt.title('Resale Price vs. Kms Driven')
plt.xlabel('Kilometers Driven')
plt.ylabel('Resale Price (Lakh)')
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_22468\358995138.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['kms_driven'] = new_df['kms_driven'].str.replace(',', '').str.replace('Kms', '').astype(float)

# %%
new_df['engine_capacity'] = new_df['engine_capacity'].str.replace(" cc", "").astype(float)

# Create a scatter plot

plt.scatter(new_df['engine_capacity'], new_df['resale_price_Lakh'], alpha=0.5, color='orange')
plt.title('Resale Price vs. Engine Capacity')
plt.xlabel('Engine Capacity (cc)')
plt.ylabel('Resale Price (Lakh)')
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_22468\3109935088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['engine_capacity'] = new_df['engine_capacity'].str.replace(" cc", "").astype(float)

# %%
new_df['transmission_type'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
# Group the data by 'fuel_type' and calculate the mean resale price for each fuel type
transmission_price_mean = new_df.groupby('transmission_type')['resale_price_Lakh'].mean()

# Plot the data
transmission_price_mean.plot(kind='bar', color='skyblue')
plt.title('Mean Resale Price by Transmission Type')
plt.xlabel('Transmission  Type')
plt.ylabel('Mean Resale Price (Lakh)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
new_df['body_type'].unique()
# Out:
# array(['Hatchback', 'SUV', 'Sedan', 'BMW', 'MUV', 'Maruti', 'Minivans',
#        'Mercedes-Benz', 'Cars', 'Coupe', 'Jaguar', 'Wagon', 'Datsun',
#        'Pickup', 'Tata', 'Honda', 'Convertibles', 'Hyundai', 'Mahindra',
#        'Volvo', 'Toyota', 'Isuzu', 'Skoda', 'Chevrolet'], dtype=object)

# %%
# Group the data by 'body_type' and calculate the mean resale price for each body type
body_type_price_mean = new_df.groupby('body_type')['resale_price_Lakh'].mean()

# Increase the figure size
plt.figure(figsize=(10, 6))

# Plot the data
body_type_price_mean.plot(kind='bar', color='skyblue')
plt.title('Mean Resale Price by Body Type')
plt.xlabel('Body Type')
plt.ylabel('Mean Resale Price (Lakh)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
new_df['engine_capacity'].unique()
# Out:
# array([1199., 1497., 1956., 1197., 2993., 1598., 1995.,  999., 2143.,
#        2987., 1248., 2498., 1194., 1364., 2179., 1451., 1999., 1498.,
#        1591., 1582., 1462., 1198., 1493.,  799., 1499., 1196.,  995.,
#        1482., 1991.,  998., 2199.,  796., 2494.,   nan, 2393., 1298.,
#        1799., 1396., 1086.,  814., 1798., 1968., 2982., 1120., 2477.,
#        1998., 1985., 3198., 1461., 1193., 1373.,  936., 1399., 1353.,
#        2925.,    0., 2967., 1896., 2148., 1997., 2354., 1950.,  624.,
#        1186., 2650., 1395., 1368., 1390., 1797., 2694., 1061., 1330.,
#        1047., 2755., 1796., 1794., 1969., 2487., 1496., 1595., 1586.,
#        2400., 2523., 1332., 2835., 2998., 1596., 1405., 2999., 2157.,
#        1108., 1597., 2184., 2956., 1341., 2996.,   72., 1490., 1993.,
#        2497., 4367., 3498., 2953., 1495., 4999., 1388., 1984., 1589.,
#        2696., 2609., 2198., 2360., 5000., 4663., 1996., 1150.,  993.,
# ...

# %%
#Transformar engine_capacity para valor numerico, remover o 'cc' e substituir os valores nulos pela média dos valores
# Extract numeric values and replace NaN with the mean in 'new_df'
new_df['engine_capacity'] = new_df['engine_capacity'].str.extract('(\d+)').astype(float)
mean_engine_capacity = new_df['engine_capacity'].mean()
new_df['engine_capacity'].fillna(mean_engine_capacity, inplace=True)

# Convert to integer
new_df['engine_capacity'] = new_df['engine_capacity'].astype(int)

new_df['engine_capacity'].isna().sum()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\migue\AppData\Local\Temp\ipykernel_22468\264700377.py:3: SyntaxWarning: invalid escape sequence '\d'
#   new_df['engine_capacity'] = new_df['engine_capacity'].str.extract('(\d+)').astype(float)
# C:\Users\migue\AppData\Local\Temp\ipykernel_22468\264700377.py:3: SyntaxWarning: invalid escape sequence '\d'
#   new_df['engine_capacity'] = new_df['engine_capacity'].str.extract('(\d+)').astype(float)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\migue\Documents\GitHub\AASE\Data Understanding.ipynb Cell 19 line 3
# ...
